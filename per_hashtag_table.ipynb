# %%
import csv

# %%
with open('parsed_new.csv', 'r') as read_obj:
        # pass the file object to reader() to get the reader object
    collected_tweets = list(csv.reader(read_obj))
        # Iterate over each row in the csv using reader object
collected_tweets
# Out:
# [['1380230026939928576',
#   'Thu Apr 08 18:44:16 +0000 2021',
#   '@BharatBiotech @SerumInstIndia @ZydusUniverse How far is this true on the scale of 10?\n#information #knowit… https://t.co/qQSyd3vvbA',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'en',
#   '0',
#   '0',
#   '598150953',
#   'Varma_Manthena',
#   'Mechanical Engineer\n\nCAE ANALYST (Automobile Domain)',
#   'Hyderabad, India',
#   'Sun Jun 03 06:11:23 +0000 2012',
#   '10',
#   '607',
#   '946',
#   '866',
#   "['information', 'knowit']"],
#  [],
#  ['1380230030429655046',
#   'Thu Apr 08 18:44:17 +0000 2021',
#   'RT @gracielaocana: No quieren que sepamos la verdad sobre el #VacunatorioVip . Pero vamos a seguir insistiendo en la Justicia.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'es',
#   '84',
#   '0',
#   '193414434',
#   'ramon miño',
#   '',
#   'lomas de zamora',
#   'Tue Sep 21 19:19:32 +0000 2010',
#   '118',
#   '462',
#   '6426',
#   '11682',
#   "['VacunatorioVip']"],
#  [],
# ...
